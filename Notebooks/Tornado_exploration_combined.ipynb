# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading the CSV document / COMBINED (Final) Dataset showing three decades of data.

# %%
df = pd.read_csv("../data/Tornado_Three_Decades_Semi_Cleaned.csv")

# %% [markdown]
# # Reading tail and head to ensure data pulled correctly. The three CSVs were combined manually via OpenOffice / Libre (Copy and paste // created new CSV entirely)

# %%
df.head()
# Out:
#    Year  Month  DAY                 TIME        STATE  YEAR     MONTH  \
# 0  2004      7   24  1900-01-01 14:30:00       NEVADA  2004      July
# 1  2004     12   29  1900-01-01 12:10:00   CALIFORNIA  2004  December
# 2  2004     12    9  1900-01-01 05:38:00  MISSISSIPPI  2004  December
# 3  2004     12    7  1900-01-01 10:15:00      INDIANA  2004  December
# 4  2004      2   27  1900-01-01 23:30:00       HAWAII  2004  February
#
#   EVENT_TYPE            SOURCE TOR_F_SCALE  TOR_LENGTH  TOR_WIDTH
# 0    Tornado    GENERAL PUBLIC          F0         0.1      200.0
# 1    Tornado   LAW ENFORCEMENT          F0         0.2        3.0
# 2    Tornado  NWS STORM SURVEY          F0         0.2       50.0
# 3    Tornado  NWS STORM SURVEY          F0         1.5       75.0
# 4    Tornado  NWS STORM SURVEY          F0         5.0       25.0

# %%
df.tail()
# Out:
#       Year  Month  DAY                 TIME      STATE  YEAR    MONTH  \
# 5135  2024      6   22  1900-01-01 17:02:00  WISCONSIN  2024     June
# 5136  2024      6   22  1900-01-01 19:22:00  WISCONSIN  2024     June
# 5137  2024      6   22  1900-01-01 19:42:00  WISCONSIN  2024     June
# 5138  2024      6   28  1900-01-01 20:02:00   MISSOURI  2024     June
# 5139  2024     10    9  1900-01-01 11:01:00    FLORIDA  2024  October
#
#      EVENT_TYPE             SOURCE TOR_F_SCALE  TOR_LENGTH  TOR_WIDTH
# 5135    Tornado   NWS Storm Survey         EF0        5.57       75.0
# 5136    Tornado   NWS Storm Survey         EF1        5.26      100.0
# 5137    Tornado   NWS Storm Survey         EF0        1.41       40.0
# 5138    Tornado  Emergency Manager         EFU        0.15       20.0
# 5139    Tornado   NWS Storm Survey         EF1        0.90      100.0

# %% [markdown]
# # Looks like the ID column (Column 1) got messed up when combining CSVs.
# Most likely due to each CSV having their own unique data ID... we are going to reset this

# %%
df.reset_index(drop=True, inplace=True) #RESET INDEX
df.insert(0, 'TORNADO_ID', df.index + 1) #INSERT NEW INDEX AT ROW 0, Column name is TORNADO_ID

# %%
#Checking again
df.head()
# Out:
#    TORNADO_ID  Year  Month  DAY                 TIME        STATE  YEAR  \
# 0           1  2004      7   24  1900-01-01 14:30:00       NEVADA  2004
# 1           2  2004     12   29  1900-01-01 12:10:00   CALIFORNIA  2004
# 2           3  2004     12    9  1900-01-01 05:38:00  MISSISSIPPI  2004
# 3           4  2004     12    7  1900-01-01 10:15:00      INDIANA  2004
# 4           5  2004      2   27  1900-01-01 23:30:00       HAWAII  2004
#
#       MONTH EVENT_TYPE            SOURCE TOR_F_SCALE  TOR_LENGTH  TOR_WIDTH
# 0      July    Tornado    GENERAL PUBLIC          F0         0.1      200.0
# 1  December    Tornado   LAW ENFORCEMENT          F0         0.2        3.0
# 2  December    Tornado  NWS STORM SURVEY          F0         0.2       50.0
# 3  December    Tornado  NWS STORM SURVEY          F0         1.5       75.0
# 4  February    Tornado  NWS STORM SURVEY          F0         5.0       25.0

# %%
df.tail()
# Out:
#       TORNADO_ID  Year  Month  DAY                 TIME      STATE  YEAR  \
# 5135        5136  2024      6   22  1900-01-01 17:02:00  WISCONSIN  2024
# 5136        5137  2024      6   22  1900-01-01 19:22:00  WISCONSIN  2024
# 5137        5138  2024      6   22  1900-01-01 19:42:00  WISCONSIN  2024
# 5138        5139  2024      6   28  1900-01-01 20:02:00   MISSOURI  2024
# 5139        5140  2024     10    9  1900-01-01 11:01:00    FLORIDA  2024
#
#         MONTH EVENT_TYPE             SOURCE TOR_F_SCALE  TOR_LENGTH  TOR_WIDTH
# 5135     June    Tornado   NWS Storm Survey         EF0        5.57       75.0
# 5136     June    Tornado   NWS Storm Survey         EF1        5.26      100.0
# 5137     June    Tornado   NWS Storm Survey         EF0        1.41       40.0
# 5138     June    Tornado  Emergency Manager         EFU        0.15       20.0
# 5139  October    Tornado   NWS Storm Survey         EF1        0.90      100.0

# %%
#Seems to be two columns ID's >> dropping the tornado ID column.
df.drop(df.columns[0], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Year  Month  DAY                 TIME        STATE  YEAR     MONTH  \
# 0  2004      7   24  1900-01-01 14:30:00       NEVADA  2004      July
# 1  2004     12   29  1900-01-01 12:10:00   CALIFORNIA  2004  December
# 2  2004     12    9  1900-01-01 05:38:00  MISSISSIPPI  2004  December
# 3  2004     12    7  1900-01-01 10:15:00      INDIANA  2004  December
# 4  2004      2   27  1900-01-01 23:30:00       HAWAII  2004  February
#
#   EVENT_TYPE            SOURCE TOR_F_SCALE  TOR_LENGTH  TOR_WIDTH
# 0    Tornado    GENERAL PUBLIC          F0         0.1      200.0
# 1    Tornado   LAW ENFORCEMENT          F0         0.2        3.0
# 2    Tornado  NWS STORM SURVEY          F0         0.2       50.0
# 3    Tornado  NWS STORM SURVEY          F0         1.5       75.0
# 4    Tornado  NWS STORM SURVEY          F0         5.0       25.0

# %%
df.tail()
# Out:
#       Year  Month  DAY                 TIME      STATE  YEAR    MONTH  \
# 5135  2024      6   22  1900-01-01 17:02:00  WISCONSIN  2024     June
# 5136  2024      6   22  1900-01-01 19:22:00  WISCONSIN  2024     June
# 5137  2024      6   22  1900-01-01 19:42:00  WISCONSIN  2024     June
# 5138  2024      6   28  1900-01-01 20:02:00   MISSOURI  2024     June
# 5139  2024     10    9  1900-01-01 11:01:00    FLORIDA  2024  October
#
#      EVENT_TYPE             SOURCE TOR_F_SCALE  TOR_LENGTH  TOR_WIDTH
# 5135    Tornado   NWS Storm Survey         EF0        5.57       75.0
# 5136    Tornado   NWS Storm Survey         EF1        5.26      100.0
# 5137    Tornado   NWS Storm Survey         EF0        1.41       40.0
# 5138    Tornado  Emergency Manager         EFU        0.15       20.0
# 5139    Tornado   NWS Storm Survey         EF1        0.90      100.0

# %% [markdown]
# # Exploratory Data Analysis!
# Now that data is combined, let's look at some overall trends. Starting with tornado length over months. However, this didn't give us anything meaningful, the data looks the same for all months. It's common knowledge that winter months are far less tornadic than summer months.

# %%
df.groupby('Month')['TOR_LENGTH'].mean()
# Out:
# Month
# 1     3.443559
# 2     3.447328
# 3     3.122039
# 4     3.584092
# 5     3.052377
# 6     2.144706
# 7     3.753838
# 8     2.240487
# 9     2.626096
# 10    3.511423
# 11    3.570247
# 12    4.275961
# Name: TOR_LENGTH, dtype: float64

# %% [markdown]
# # Instead, lets look at the number of EF tornadoes by months!

# %%
ef_counts_month = df.groupby(['MONTH', 'TOR_F_SCALE']).size()
pd.set_option('display.max_rows', None) #Display max rows to none allows us to see all of the data, otherwise pandas will limit what we can see...
print(ef_counts_month)
# Out:
# MONTH      TOR_F_SCALE
# April      EF0            158
#            EF1            270
#            EF2             78
#            EF3             22
#            EF4              5
#            EFU             48
#            F0              97
#            F1              32
#            F2               5
#            F3               1
# August     EF0             98
#            EF1             48
#            EF2              4
#            EF3              1
#            EFU             18
#            F0             140
#            F1              34
#            F2               6
# December   EF0             69
#            EF1             89
#            EF2              6
#            EF3              5
#            EFU              3
#            F0              17
#            F1               8
#            F2               5
#            F3               1
# February   EF0             41
#            EF1             48
#            EF2             13
#            EFU              4
#            F0               6
#            F1               3
#            F2               1
# January    EF0             24
#            EF1             24
#            EF2              6
#            EF3              1
#            EFU              1
#            F0               2
#            F2               1
# July       EF0            139
#            EF1            154
#            EF2             23
#            EF3              3
#            EFU             35
#            F0              93
#            F1              27
#            F2               5
#            F3               1
#            F4               2
# June       EF0            228
#            EF1            169
#            EF2             32
#            EF3              7
#            EF4              6
#            EFU             41
#            F0             206
#            F1              61
#            F2               6
#            F3               9
# March      EF0             37
#            EF1             34
#            EF2             14
#            EF3              3
#            EFU             10
#            F0              36
#            F1              15
#            F2               2
#            F3               1
# May        EF0            314
#            EF1            300
#            EF2             70
#            EF3             29
#            EF4              2
#            EFU             80
#            F0             333
#            F1             162
#            F2              32
#            F3              10
#            F4               6
# November   EF0             33
#            EF1             45
#            EF2              4
#            EF3              4
#            EFU             23
#            F0             100
#            F1              48
#            F2              23
#            F3               3
# October    EF0             48
#            EF1             79
#            EF2             11
#            EF3              3
#            EFU              8
#            F0              55
#            F1              28
#            F2               7
# September  EF0             67
#            EF1             40
#            EF2              4
#            EF3              1
#            EFU              9
#            F0             186
#            F1             102
#            F2              27
#            F3               2
# dtype: int64

# %% [markdown]
# # Problem #1 > Two different tornado scales being used by the CSVs.
#
# This is a problem for data analysis as the enchanced fujita scale rates tornadoes differently based on Wind speed, damage, etc...
#
# So we will need to use ONE scale or drop this column entirely and not rely on it for analysis... an F5 tornado is NOT the same as an EF5
#
# We need to look at what were attempting to do going forward. Our MAIN question here is tracking tornado alley... if it has shifted across the United States
#
# This column is a categorical, and we still have other columns to rely upon for more detailed information about the tornados.
#
# I am electing to do a rough conversion from the older F scale into the new EF 5 scale... the scale is pretty 1 to 1 until we reach EF3 and above.
#
# This will be taken into account further along...

# %% [markdown]
# # Creating a dictionary for conversion.

# %%
f_to_ef = {'F0':'EF0', 'F1':'EF1', 'F2':'EF2', 'F3':'EF3', 'F4':'EF4', 'F5':'EF5'}
df['TOR_SCALE_UNIFIED'] = df['TOR_F_SCALE'].replace(f_to_ef)

# %%
#Looking at head to make sure it worked correctly.
df.head()
# Out:
#    Year  Month  DAY                 TIME        STATE  YEAR     MONTH  \
# 0  2004      7   24  1900-01-01 14:30:00       NEVADA  2004      July
# 1  2004     12   29  1900-01-01 12:10:00   CALIFORNIA  2004  December
# 2  2004     12    9  1900-01-01 05:38:00  MISSISSIPPI  2004  December
# 3  2004     12    7  1900-01-01 10:15:00      INDIANA  2004  December
# 4  2004      2   27  1900-01-01 23:30:00       HAWAII  2004  February
#
#   EVENT_TYPE            SOURCE TOR_F_SCALE  TOR_LENGTH  TOR_WIDTH  \
# 0    Tornado    GENERAL PUBLIC          F0         0.1      200.0
# 1    Tornado   LAW ENFORCEMENT          F0         0.2        3.0
# 2    Tornado  NWS STORM SURVEY          F0         0.2       50.0
# 3    Tornado  NWS STORM SURVEY          F0         1.5       75.0
# 4    Tornado  NWS STORM SURVEY          F0         5.0       25.0
#
#   TOR_SCALE_UNIFIED
# 0               EF0
# 1               EF0
# 2               EF0
# 3               EF0
# 4               EF0

# %% [markdown]
# Now that it is combined, let's trying looking at the data again.

# %%
ef_counts_month = df.groupby(['MONTH', 'TOR_SCALE_UNIFIED']).size() #NEW COLUMN USING COMBINED EF SCALE
pd.set_option('display.max_rows', None)
print(ef_counts_month)
# Out:
# MONTH      TOR_SCALE_UNIFIED
# April      EF0                  255
#            EF1                  302
#            EF2                   83
#            EF3                   23
#            EF4                    5
#            EFU                   48
# August     EF0                  238
#            EF1                   82
#            EF2                   10
#            EF3                    1
#            EFU                   18
# December   EF0                   86
#            EF1                   97
#            EF2                   11
#            EF3                    6
#            EFU                    3
# February   EF0                   47
#            EF1                   51
#            EF2                   14
#            EFU                    4
# January    EF0                   26
#            EF1                   24
#            EF2                    7
#            EF3                    1
#            EFU                    1
# July       EF0                  232
#            EF1                  181
#            EF2                   28
#            EF3                    4
#            EF4                    2
#            EFU                   35
# June       EF0                  434
#            EF1                  230
#            EF2                   38
#            EF3                   16
#            EF4                    6
#            EFU                   41
# March      EF0                   73
#            EF1                   49
#            EF2                   16
#            EF3                    4
#            EFU                   10
# May        EF0                  647
#            EF1                  462
#            EF2                  102
#            EF3                   39
#            EF4                    8
#            EFU                   80
# November   EF0                  133
#            EF1                   93
#            EF2                   27
#            EF3                    7
#            EFU                   23
# October    EF0                  103
#            EF1                  107
#            EF2                   18
#            EF3                    3
#            EFU                    8
# September  EF0                  253
#            EF1                  142
#            EF2                   31
#            EF3                    3
#            EFU                    9
# dtype: int64

# %% [markdown]
# # Problem #2 > "EFU"
# We have "EFU" which stands for Unknown. These are tornadoes that aren't assigned to the EF scale. Possible reasons due to lack of information (damage to buildings) or lack of direct observation (Such as a radar spotted or radar).
#
# Creating another new dictionary... labeling these tornadoes "unknown" for clarity.

# %%
df['TOR_SCALE_UNIFIED'] = df['TOR_SCALE_UNIFIED'].replace({'EFU': 'Unknown'})
ef_counts_month = df.groupby(['MONTH', 'TOR_SCALE_UNIFIED']).size()
pd.set_option('display.max_rows', None)
print(ef_counts_month)
# Out:
# MONTH      TOR_SCALE_UNIFIED
# April      EF0                  255
#            EF1                  302
#            EF2                   83
#            EF3                   23
#            EF4                    5
#            Unknown               48
# August     EF0                  238
#            EF1                   82
#            EF2                   10
#            EF3                    1
#            Unknown               18
# December   EF0                   86
#            EF1                   97
#            EF2                   11
#            EF3                    6
#            Unknown                3
# February   EF0                   47
#            EF1                   51
#            EF2                   14
#            Unknown                4
# January    EF0                   26
#            EF1                   24
#            EF2                    7
#            EF3                    1
#            Unknown                1
# July       EF0                  232
#            EF1                  181
#            EF2                   28
#            EF3                    4
#            EF4                    2
#            Unknown               35
# June       EF0                  434
#            EF1                  230
#            EF2                   38
#            EF3                   16
#            EF4                    6
#            Unknown               41
# March      EF0                   73
#            EF1                   49
#            EF2                   16
#            EF3                    4
#            Unknown               10
# May        EF0                  647
#            EF1                  462
#            EF2                  102
#            EF3                   39
#            EF4                    8
#            Unknown               80
# November   EF0                  133
#            EF1                   93
#            EF2                   27
#            EF3                    7
#            Unknown               23
# October    EF0                  103
#            EF1                  107
#            EF2                   18
#            EF3                    3
#            Unknown                8
# September  EF0                  253
#            EF1                  142
#            EF2                   31
#            EF3                    3
#            Unknown                9
# dtype: int64

# %% [markdown]
# The above data is telling us that the EF scale isn't something we should rely on heavily for tracking the strength of tornados, we can still use it but we should rely on other columns (that use numerical data) for a more reliable analysis.
#
# Lets look at something else this time, perhaps how many tornados per state.

# %%
df.head()
# Out:
#    Year  Month  DAY                 TIME        STATE  YEAR     MONTH  \
# 0  2004      7   24  1900-01-01 14:30:00       NEVADA  2004      July
# 1  2004     12   29  1900-01-01 12:10:00   CALIFORNIA  2004  December
# 2  2004     12    9  1900-01-01 05:38:00  MISSISSIPPI  2004  December
# 3  2004     12    7  1900-01-01 10:15:00      INDIANA  2004  December
# 4  2004      2   27  1900-01-01 23:30:00       HAWAII  2004  February
#
#   EVENT_TYPE            SOURCE TOR_F_SCALE  TOR_LENGTH  TOR_WIDTH  \
# 0    Tornado    GENERAL PUBLIC          F0         0.1      200.0
# 1    Tornado   LAW ENFORCEMENT          F0         0.2        3.0
# 2    Tornado  NWS STORM SURVEY          F0         0.2       50.0
# 3    Tornado  NWS STORM SURVEY          F0         1.5       75.0
# 4    Tornado  NWS STORM SURVEY          F0         5.0       25.0
#
#   TOR_SCALE_UNIFIED
# 0               EF0
# 1               EF0
# 2               EF0
# 3               EF0
# 4               EF0

# %%
tornado_per_state = df.groupby(['YEAR', 'STATE']).size()
pd.set_option('display.max_rows', None)
print(tornado_per_state)
# Out:
# YEAR  STATE
# 2004  ALABAMA            65
#       ALASKA              2
#       ARIZONA             3
#       ARKANSAS           58
#       CALIFORNIA         10
#       COLORADO           84
#       DELAWARE            2
#       FLORIDA           107
#       GEORGIA            46
#       HAWAII              3
#       IDAHO               5
#       ILLINOIS           87
#       INDIANA            53
#       IOWA              124
#       KANSAS            125
#       KENTUCKY           23
#       LOUISIANA          30
#       MAINE               1
#       MARYLAND           21
#       MASSACHUSETTS       2
#       MICHIGAN           24
#       MINNESOTA          61
#       MISSISSIPPI        69
#       MISSOURI           80
#       MONTANA             7
#       NEBRASKA          116
#       NEVADA              5
#       NEW HAMPSHIRE       1
#       NEW JERSEY          2
#       NEW MEXICO         11
#       NEW YORK            9
#       NORTH CAROLINA     70
#       NORTH DAKOTA       50
#       OHIO                9
#       OKLAHOMA           65
#       OREGON              7
#       PENNSYLVANIA       26
#       PUERTO RICO         1
#       SOUTH CAROLINA     89
#       SOUTH DAKOTA       35
#       TENNESSEE          18
#       TEXAS             185
#       VIRGINIA           94
#       WASHINGTON          9
#       WEST VIRGINIA       4
#       WISCONSIN          43
#       WYOMING             6
# 2014  ALABAMA            67
#       ARIZONA             3
#       ARKANSAS           25
#       CALIFORNIA          9
#       COLORADO           50
#       CONNECTICUT         1
#       DELAWARE            1
#       FLORIDA            30
#       GEORGIA            43
#       IDAHO               3
#       ILLINOIS           60
#       INDIANA            35
#       IOWA              113
#       KANSAS             41
#       KENTUCKY           29
#       LOUISIANA          17
#       MAINE               4
#       MARYLAND            3
#       MASSACHUSETTS       3
#       MICHIGAN           14
#       MINNESOTA          28
#       MISSISSIPPI        51
#       MISSOURI           51
#       MONTANA             8
#       NEBRASKA           74
#       NEVADA              6
#       NEW HAMPSHIRE       2
#       NEW MEXICO         14
#       NEW YORK           12
#       NORTH CAROLINA     37
#       NORTH DAKOTA       15
#       OHIO               21
#       OKLAHOMA           16
#       PENNSYLVANIA       10
#       SOUTH CAROLINA      7
#       SOUTH DAKOTA       30
#       TENNESSEE          20
#       TEXAS              47
#       VIRGINIA           14
#       WASHINGTON          3
#       WEST VIRGINIA      11
#       WISCONSIN          23
#       WYOMING            13
# 2024  ALABAMA            80
#       ALASKA              1
#       ARIZONA             7
#       ARKANSAS           62
#       CALIFORNIA          4
#       COLORADO           21
#       CONNECTICUT         1
#       DELAWARE            1
#       FLORIDA           127
#       GEORGIA            38
#       IDAHO               1
#       ILLINOIS          174
#       INDIANA            73
#       IOWA              155
#       KANSAS             69
#       KENTUCKY           66
#       LOUISIANA         108
#       MARYLAND           13
#       MASSACHUSETTS       2
#       MICHIGAN           18
#       MINNESOTA          34
#       MISSISSIPPI        94
#       MISSOURI          119
#       MONTANA             4
#       NEBRASKA          115
#       NEW HAMPSHIRE       2
#       NEW JERSEY          1
#       NEW MEXICO         12
#       NEW YORK           33
#       NORTH CAROLINA     46
#       NORTH DAKOTA       14
#       OHIO               90
#       OKLAHOMA          178
#       OREGON              3
#       PENNSYLVANIA       24
#       PUERTO RICO         1
#       RHODE ISLAND        1
#       SOUTH CAROLINA     57
#       SOUTH DAKOTA        7
#       TENNESSEE          23
#       TEXAS             149
#       UTAH                2
#       VIRGINIA           14
#       WASHINGTON          4
#       WEST VIRGINIA      21
#       WISCONSIN          55
#       WYOMING             5
# dtype: int64

# %% [markdown]
# This tells us some basic information we already know, for example, we know that a state such as Maine doesn't get many tornadoes, it isn't even on the list!
#
# But we do see that states such as Nebraska get a good amount of tornadoes.
#
# But if our main objective is to look at if tornados are shifting eastward, let's pick a state outside of the traditional tornado alley, such as Kentucky.

# %%
print(df[df['STATE'] == 'KENTUCKY'].groupby('YEAR').size())
# Out:
# YEAR
# 2004    23
# 2014    29
# 2024    66
# dtype: int64

# %% [markdown]
# Interesting, this is telling us that there are MORE tornados over the most recent decade in KY compared to two decades ago. More than double!

# %% [markdown]
# # Let's trying using some graphics to look at this data.
#
# I am electing to use a bar graph to illustrate tornadoes per year in the United States, as bar graphs are great for showing the amount of instances divided over buckets. A simple 3 bucket method showing the three decades should draw out a pattern for us to analyze

# %%
#Creating a bar graph showing Number of Tornadoes per year
tornado_per_year = df.groupby('YEAR').size()

plt.figure(figsize=(12,6))
tornado_per_year.plot(kind='bar', color='darkred')
plt.title('Total Tornado count across the United States', fontsize=24, fontweight="bold")
plt.xlabel('Year',fontsize=24, fontweight="bold", labelpad=24)
plt.ylabel('Tornado Count', labelpad=24, fontsize=20, fontweight="bold")
plt.xticks(rotation=360, fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# The number of tornados has slightly increased in 2024 compared to 2004, but look at the huge dip in 2014.
#
# This may be an anomally or a pattern. If I had to choose one, I would opt for this to be an anomally since tornado count increased in 2024.
#
# Below we are pulling columns names again to make it easier to create future graphs.

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'DAY', 'TIME', 'STATE', 'YEAR', 'MONTH', 'EVENT_TYPE',
#        'SOURCE', 'TOR_F_SCALE', 'TOR_LENGTH', 'TOR_WIDTH',
#        'TOR_SCALE_UNIFIED'],
#       dtype='object')

# %% [markdown]
# # Now let's analyze the average tornado length per year
#
# If we want to see if tornados are getting stronger (another goal for this project), tornado length (instead of EF scale) should be a good point of analysis.
#
# I have decided on a line graph, as line graphs are fantastic for showing trends over a period of time.

# %%
plt.figure(figsize=(12,6))

# Group by year and calculate average tornado length
avg_length_per_year = df.groupby('YEAR')['TOR_LENGTH'].mean()

plt.plot(avg_length_per_year.index, avg_length_per_year.values, marker='o', linewidth=10,color="darkred")
plt.title('Average Tornado Length per Year',fontsize=30,pad=30,fontweight="bold")
plt.xlabel('Year',fontsize=20,labelpad=20,fontweight="bold")
plt.xticks(rotation=360, fontsize=16)
plt.ylabel('Average Tornado Length (miles)',fontsize=20,labelpad=20,fontweight="bold")
plt.yticks(fontsize=16)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# The graph above shows us that tornado length is steadily increasing since the data starts in 2004, growing almost a whole mile since 2004!
#
# Let's look at Kentucky (KY) specifically and see if this is also true to an Eastern state.
#
# I decided on a histogram for this, as histograms allow us to see multiple points of data for one specific entitiy (KY).

# %%
palette = [
    "#00FF73",
    "#FF01C8",
    "#022BB3",
    "#F4A261",
    "#E76F51"
]

df_ky = df[df['STATE'] == 'KENTUCKY'] # Dataframe is equal to where state is KY
years = sorted(df_ky['YEAR'].unique()) #Sorting by unique instances of tornadoes
               
plt.figure(figsize=(12,6))

for i, year in enumerate(years): #Since we are using specific colors, we use i / enumerate instead of a traditional for loop
    data = df_ky[df_ky['YEAR'] == year]['TOR_LENGTH']
    plt.hist(
        data,
        bins=20,
        alpha=0.5,
        color=palette[i % len(palette)],  
        label=str(year)
    )


plt.title('Tornado Length Distribution per Year in Kentucky (KY)',fontweight="bold",fontsize=25,pad=15)
plt.xlabel('Length (miles)',fontsize=20,fontweight="bold",labelpad=10)
plt.xticks(fontsize=15)
plt.ylabel('Tornado count in KY',fontsize=20,fontweight="bold",labelpad=10)
plt.yticks(fontsize=15)
plt.legend(title='Year', bbox_to_anchor=(1.05, 1), loc='upper left',title_fontsize=22,fontsize=15,)
plt.tight_layout()
plt.show()

# %% [markdown]
# Histogram above shows that in KY, Tornado Length seems to be getting larger in later decades.
