# %%
import pandas as pd

# %%
df = pd.read_csv("StormEvents_details-ftp_v1.0_d2024_c20251118.csv")

# %%
df.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           202404         30        2033         202404       30      2033
# 1           202407          1           0         202407        5       900
# 2           202411         16         230         202411       18      1421
# 3           202405         22        1230         202405       22      1615
# 4           202405         21        1200         202405       21      1530
#
#    EPISODE_ID  EVENT_ID      STATE  STATE_FIPS  ...  END_RANGE END_AZIMUTH  \
# 0      189851   1174463   OKLAHOMA          40  ...        0.0         SSW
# 1      193486   1195301  LOUISIANA          22  ...        NaN         NaN
# 2      197838   1223377     OREGON          41  ...        NaN         NaN
# 3      191723   1184135      TEXAS          48  ...        NaN         NaN
# 4      191723   1184133      TEXAS          48  ...        NaN         NaN
#
# ...
